# %% [raw]
# In the provided code snippet, several functions and methods are defined and called within the context of managing projection directions for a data analysis project. Here is a breakdown of the different functions and methods called:
#
# Enum Methods
#
# 1. from_index(idx: int) -> 'Sense': A static method in the Sense enum class that returns the Sense enum (FWD or REV) based on the provided index.
# 2. to_index(self) -> int: A method in the Sense enum class that returns an index based on the enum value (FWD or REV).
#
# Class Initializers
#
# 1. __init__(self): Initializer methods are defined for the classes Anchor and _ProjectionDirections. These methods set up the initial state of an object when it is created.
#
# _ProjectionDirections Methods
#
# 1. load(self, pd_file=None): Loads the projection direction data from a file. If pd_file is not specified, it uses a default path from the p object.
# 2. save(self): Saves the current state of the projection direction data to a file specified in the p object.
# 3. update(self): Updates the projection direction data based on the current configuration and data. This method involves several steps, including loading existing data if available, recalculating projection direction information, and saving the updated data.
# 4. insert_anchor(self, id: int, anchor: Anchor): Inserts an Anchor object into the anchors dictionary with the specified id.
# 5. remove_anchor(self, id: int): Removes an anchor from the anchors dictionary based on the specified id.
# 6. deduplicate(self, arr): A utility method to remove duplicate entries from an array based on a midpoint calculation.
#
# Property Methods
#
# Various @property methods are defined to provide easy access to specific attributes of the _ProjectionDirections class, such as occupancy_no_duplication, bin_centers_no_duplication, anchor_ids, thresholded_image_indices, occupancy, n_bins, and n_thresholded.
#
# Utility Functions
#
# 1. get_cluster_ids(G): A function defined within the update method to assign cluster IDs based on connected components in the neighbor graph.
#
# External Function Calls
#
# 1. get_align_data(p.align_param_file, flip=True): This function processes data alignment from a file.
# 2. augment(q): This function augments the quaternion data.
# 3. bin_and_threshold(q, p.ang_width, p.PDsizeThL, p.PDsizeThH): This function is responsible for binning and thresholding projection direction data.
#
# These functions and methods collectively manage the projection direction data, including loading, saving, updating, and processing.

# %% [raw]
# These two lines of Python code are related to configuring logging for the script.
#
# 1. _logger = logging.getLogger(__name__): This line creates a logger object for the current module. The logging module in Python is used to track events that happen when a software runs. The getLogger method is used to get a logger instance. The __name__ variable in Python is a special variable that holds the name of the current module. If this line is executed in a script that is run directly, __name__ will be '__main__', otherwise, it will be the name of the module (file) in which this code resides. This allows for module-specific logging, as we can configure different loggers for different modules if you wish.
#
# 2. _logger.setLevel(logging.DEBUG): This line sets the logging level of the _logger object to DEBUG. The logging level determines the severity of the messages that the logger will handle. There are several logging levels available (in increasing order of severity): DEBUG, INFO, WARNING, ERROR, and CRITICAL. By setting the logger level to DEBUG, we are configuring the logger to handle all messages from DEBUG and above. This means it will capture detailed information useful for diagnosing problems, as well as higher-level log messages like informational messages, warnings, errors, and critical issues.

# %%
_logger = logging.getLogger(__name__)
_logger.setLevel(logging.DEBUG)

# %% [raw]
# ##############################################################################################################
#
# The @dataclass decorator is a feature introduced in Python 3.7 as part of the dataclasses module. It is used to automatically generate special methods for classes that primarily store data, such as __init__, __repr__, __eq__, and __hash__ among others. This simplifies the process of creating classes that are mostly used as containers for data fields.
#
# Here is a quick overview of when and why we might use @dataclass:
#
# When to Use @dataclass:
#
# 1. Simplifying Class Definitions: When we have a class that primarily serves to hold data with little to no functionality (methods) beyond storing that data. Traditional classes require manually defining methods like __init__ and __repr__ to make them useful, which can be verbose and repetitive for simple data containers.
#
# 2. Automatic Method Generation: If we want Python to automatically generate __init__, __repr__, __eq__, and optionally __hash__ methods for us, based on the class fields we define. This can save time and reduce errors in boilerplate code.
#
# 3. Immutability Option: When we need immutable instances, we can use the frozen parameter (@dataclass(frozen=True)) to make the instances of our class immutable. This is useful for creating objects that should not change after they are created, similar to tuples.
#
# 4. Type Hints Integration: @dataclass works well with type hints, allowing us to specify the type of each field in your class, which can improve code readability and help with static type checking.
#
# The FilterParams class is a Python data class designed to encapsulate parameters and functionality for creating image filters, specifically Gaussian and Butterworth filters. The class uses Python's @dataclass decorator from the dataclasses module, which automatically adds special methods including __init__, __repr__, and others to the class based on the defined fields. This makes it easier to work with instances of the class without having to manually define these methods.
#
# Fields
#
# 1. method: A string indicating the type of filter to create. It supports 'Gauss' for Gaussian filters and 'Butter' for Butterworth filters.
# 2. cutoff_freq: A floating-point number representing the Nyquist cutoff frequency of the filter.
# 3. order: An integer specifying the order of the filter. This is applicable only for Butterworth filters.
#
# Method: create_filter
# The create_filter method takes a 2D NumPy array Q, which represents the frequency domain coordinates, and returns a 2D NumPy array representing the filter in the frequency domain.
# If method is 'Gauss', it calculates the Gaussian filter.
# If method is 'Butter', it calculates the Butterworth filter.
# If method is neither 'Gauss' nor 'Butter', it logs an error message and raises a ValueError.
#
# Usage
#
# This class can be used to create filters for image processing tasks, such as smoothing or noise reduction, in the frequency domain. Here's an example of how you might use this class:
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# rotate_fill: The rotate_fill function is designed to rotate an image by a specified angle and then extract the central part of the resulting image. This function is particularly useful in image processing tasks where rotation without losing parts of the image or introducing empty (black) borders is desired.
#
# Parameters
#
# 1. img: A 2D NumPy array representing the image to be rotated. The shape of img is expected to be square (*,*), meaning the number of rows and columns should be equal.
# 2. angle: A floating-point value representing the angle (in degrees) by which the image should be rotated.
#
# Process
#
# 1. Determine Image Size: The function first determines the size (n_pix) of the input image by accessing its shape. Since the image is expected to be square, either dimension can be used to find the size.
# 2. Create an Expanded Image: The input image is tiled (repeated) 3 times both horizontally and vertically using np.tile(img, (3, 3)). This creates a larger image composed of 9 copies of the original image arranged in a 3x3 grid. This step is crucial for ensuring that rotating the image does not introduce empty borders and that the central part of the image still contains relevant content after rotation.
# 3. Convert to PIL Image: The expanded NumPy array is converted to a PIL (Python Imaging Library, now known as Pillow) image using Image.fromarray(...). This conversion is necessary because the rotation is performed using PIL's rotate method, which provides more flexibility and options for image manipulation compared to NumPy's capabilities.
# 4. Rotate the Image: The expanded image is rotated by the specified angle using PIL's rotate method. The expand=False parameter indicates that the output image should not be resized to fit the rotated image; instead, the rotated image will be cropped to the original expanded image size.
# 5. Extract the Central Part: After rotation, the central part of the rotated image is extracted. This is done by selecting the middle third of the image in both dimensions, effectively returning to the original image size but with the content rotated. This step ensures that the output image does not contain any empty borders introduced by rotation and maintains the original image size.
# 6. Convert Back to NumPy Array: The resulting PIL image is converted back to a NumPy array with the same data type (dtype) as the input image.
#
# Return Value
#
# The function returns a NumPy array representing the rotated image, with the same dimensions as the input image.
#
# This function is particularly useful in contexts where images need to be aligned or oriented in a specific direction as part of preprocessing steps, such as in computer vision tasks, image analysis, or scientific research involving image data.
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# create_grid: The create_grid function generates a 2D grid of values representing the normalized distance from the center of the grid to each point. This grid is particularly useful in image processing and scientific computing for operations that require knowledge of each pixel's relative position to the center of an image or a matrix.
#
# Parameters
#
# 1. N: An integer specifying the size of the grid. The grid will be N by N elements.
#
# Process
#
# 1. Generate Coordinate Arrays: The function starts by creating an array a that ranges from -(N//2) to (N//2) - 1, effectively creating a sequence of integers centered around 0. This sequence represents the coordinates along one axis of the grid.
# 2. Create Meshgrid: The np.meshgrid function takes two 1D arrays and produces two 2D matrices corresponding to all pairs of (x, y) in the two arrays. In this case, X and Y are both 2D arrays where each element in X contains the x-coordinate of the grid, and each element in Y contains the y-coordinate. The grid is centered around (0, 0) because of how a is constructed.
# 3. Calculate Normalized Distances: The function calculates the Euclidean distance from the center for each point in the grid using the formula sqrt(X^2 + Y^2). This distance is then normalized by dividing by N, the size of the grid, and multiplied by 2 to scale the distances appropriately.
#
# Return Value
#
# The function returns a 2D NumPy array (NDArray[Shape["*,*"], Float64]) of shape N by N, where each element represents the normalized distance of that point from the center of the grid.
#
# Usage
#
# This grid can be used in various applications, such as:
# 1. Generating radial frequency filters in Fourier domain image processing.
# 2. Creating circular or radial masks for images.
# 3. Simulating physical phenomena that depend on radial distance from a central point.
# The normalization ensures that the distance values are scaled relative to the size of the grid, making the function versatile for grids of different sizes.
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# quats_to_unit_vecs: The quats_to_unit_vecs function converts a set of quaternions to unit vectors representing average projection directions. This function is particularly useful in 3D graphics, robotics, and physics, where quaternions are commonly used to represent rotations due to their compactness and ability to avoid gimbal lock compared to Euler angles.
#
# Parameters
#
# 1. q: A NumPy array of shape [4,*], where each column represents a quaternion. A quaternion is a four-dimensional vector used for encoding rotations, typically consisting of one real part and three imaginary parts.
#
# Process
#
# 1. Vectorized Operations: The function performs vectorized operations on the input quaternions to compute the corresponding unit vectors. The operations are based on quaternion algebra, where the rotation encoded by a quaternion can also be represented as a direction in 3D space.
#
# Calculations
#
# 1. The function calculates three components of the unit vectors using the input quaternions. These components are derived from the quaternion components [w, x, y, z] (represented here as [q[0, :], q[1, :], q[2, :], q[3, :]]):
#     (a) The first component is calculated as 2 * (q[1, :] * q[3, :] - q[0, :] * q[2, :]).
#     (b) The second component is 2 * (q[0, :] * q[1, :] + q[2, :] * q[3, :]).
#     (c) The third component is 2 * (q[0, :]**2 + q[3, :]**2) - np.ones((1, q.shape[1])) / 2.0. This represents a normalized direction vector in 3D space corresponding to the rotation encoded by the quaternion.
# 2. Stacking: The calculated components are vertically stacked (np.vstack) to form a 2D array where each column represents a unit vector in 3D space. The resulting array has a shape of [3,*], indicating three components (x, y, z) for each vector.
#
# Return Value
#
# The function returns a NumPy array of shape [3,*], where each column is a unit vector in 3D space derived from the corresponding input quaternion. These vectors represent the average projection directions encoded by the input quaternions.
# Usage
# This function is useful in applications where it's necessary to convert quaternion-based rotations to a more intuitive representation as direction vectors in 3D space, such as visualizing rotations, performing geometric transformations, or analyzing the orientation of objects in 3D simulations or real-world robotics tasks.
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# get_psi: The get_psi function calculates the in-plane rotation angle, denoted as ψ, between a reference vector and the rotation encoded by a quaternion. This function is useful in 3D geometry and physics, where understanding the relative orientation between objects or reference frames is important.
#
# Parameters
#
# 1. q: A NumPy array of shape [4], representing a quaternion. Quaternions are a method of encoding rotations in 3D space, consisting of one real part and three imaginary parts.
# 2. ref_vec: A NumPy array of shape [3], representing a reference vector in 3D space. This vector is used as a basis for calculating the in-plane rotation angle relative to the rotation encoded by the quaternion.
#
# Process
#
# 1. Calculate Sine and Cosine Components: The function calculates the sine and cosine components of the angle ψ using the components of the quaternion and the reference vector. These calculations are based on the relationship between the quaternion's rotation and the reference vector's orientation in 3D space.
# 2. Determine ψ: The function then calculates the angle ψ based on the sine and cosine components. The angle is calculated using the two-argument arctangent function, which takes into account the signs of both sine and cosine to determine the correct quadrant for the angle:
#
# Return Value
#
# The function returns a floating-point value representing the angle ψ in radians. This angle indicates the in-plane rotation between the reference vector and the orientation encoded by the quaternion.
#
# Usage
#
# This function can be used in various applications involving 3D rotations, such as robotics, computer graphics, and aerospace engineering, where it's necessary to understand the relative orientation of objects or coordinate frames. Specifically, it helps in determining how much an object needs to be rotated in-plane to align with a given reference direction.
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# psi_ang: The psi_ang function calculates the angle ψ (in degrees) of a reference vector in 3D space, converting it into a quaternion representation and then using a specific conversion method (q2Spider) to obtain the angle. This function is useful in contexts where orientations or rotations are analyzed or applied, such as in computer graphics, robotics, or physics simulations.
#
# Parameters
#
# 1. ref_vec: A NumPy array of shape [3], representing a reference vector in 3D space. This vector is used to calculate the corresponding angle ψ.
#
# Process
#
# 1. Quaternion Representation: The function first constructs a quaternion Qr from the input reference vector ref_vec. The quaternion is formed as [1 + ref_vec[2], ref_vec[1], -ref_vec[0], 0]. This specific construction is part of transforming the reference vector into a quaternion that represents a rotation.
# 2. Normalization: The quaternion Qr is then normalized to ensure it represents a valid rotation. The normalization is done by dividing Qr by its length squared (L2), which is calculated as the sum of the squares of its components.
# 3. Angle Calculation: The normalized quaternion Qr is passed to the q2Spider function. The q2Spider function is assumed to convert the quaternion into Euler angles or another form from which the ψ angle can be extracted. The specifics of q2Spider are not provided, but it likely follows conventions used in specific applications or software packages for representing rotations.
# The angle ψ obtained from q2Spider is then adjusted to ensure it is within the correct range and converted from radians to degrees.
#
# Return Value
#
# The function returns the angle ψ in degrees, representing the orientation of the input reference vector in 3D space after being converted to a quaternion and processed through the q2Spider function.
#
# Usage
#
# This function can be particularly useful in scenarios where it is necessary to convert 3D vectors into angles for analysis, visualization, or application of rotations. The conversion to quaternion and subsequent processing through q2Spider suggest that the function is tailored to specific conventions or requirements, possibly related to a particular field of study or software package.
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# get_wiener1: The get_wiener1 function is designed to compute the denominator part of the Wiener filter used in image processing, particularly in the context of cryo-electron microscopy (cryo-EM) where Contrast Transfer Function (CTF) correction is applied. The Wiener filter is a fundamental tool in signal processing for noise reduction and deconvolution, aiming to restore the original signal from a noisy one by minimizing the mean square error.
#
# Parameters
#
# 1. CTF1: A numpy array representing the Contrast Transfer Function values for a set of images. The array is expected to have a shape that accommodates multiple images (e.g., [number_of_images, height, width]).
#
# Process Overview
#
# 1. Initialization: The function starts with setting the signal-to-noise ratio (SNR) to 5, a chosen value that represents the balance between the signal and noise in the images. The variable wiener_dom is initialized to 0.0, which will accumulate the sum of squared CTF values across all images.
# 2. Accumulating Squared CTF Values: The function iterates over each image (or each slice of the CTF1 array along the first dimension) and accumulates the sum of squared CTF values. This is done by squaring the CTF values of each image (CTF1[i, :, :]**2) and adding them to wiener_dom.
# 3. Adjusting for SNR: After accumulating the squared CTF values, the function adjusts this sum by adding the reciprocal of the SNR (1. / SNR). This step incorporates the noise level into the calculation, which is crucial for the Wiener filter's effectiveness in noise reduction.
# 4. Returning the Wiener Filter Denominator: The final value of wiener_dom represents the denominator of the Wiener filter for the given set of images and their CTF values. This value is returned by the function.
#
# Key Points
#
# 1. The Wiener filter is used to improve image quality by considering both the signal and the noise characteristics. The denominator calculated by this function is a critical component of the Wiener filter formula.
# 2. The choice of SNR affects the filtering result. A higher SNR value implies less noise in the images, while a lower SNR value indicates more noise. Adjusting the SNR can fine-tune the balance between noise reduction and signal preservation.
# 3. This function specifically deals with the CTF correction aspect of image processing in cryo-EM, highlighting its role in enhancing the quality of microscopy images for better analysis and interpretation.
#
# ##############################################################################################################

# %% [raw]
# ##############################################################################################################
#
# ctemh_cryoFrank: The ctemh_cryoFrank function is designed to compute the Contrast Transfer Function (CTF) for cryo-electron microscopy (cryo-EM) images, incorporating several key parameters that influence the shape of CTF and behavior. This function is based on principles from electron microscopy physics and is adapted from Kirkland's work, with modifications for cryo-EM by Peter Schwander and further adaptations to Python by Hstau Liao and others.
#
# Input Parameters
#
# 1. k: A 2D numpy array representing spatial frequencies at which the CTF is to be evaluated.
# spherical_aberration (Cs): The spherical aberration coefficient of the microscope's objective lens, in millimeters.
# 2. defocus (df): The defocus value, in Angstroms. A positive value indicates underfocus.
# 3. electron_energy: The acceleration voltage of the electron beam, in kilo-electron volts (keV).
# 4. gauss_env_halfwidth (B): The half-width of the Gaussian envelope function, in inverse square Angstroms (A^-2), characterizing the damping envelope.
# 5. amplitude_contrast_ratio: The ratio of amplitude contrast, obtained from alignment files, which affects the phase contrast in the images.
#
# Process Overview
#
# 1. Physical Constants and Parameters: The function calculates the electron wavelength (wav) using the electron rest mass (mo), Planck constant (hc), and electron energy. This wavelength is crucial for understanding how electrons interact with the sample.
#
# CTF Calculation:
#
# 1. The function calculates two key components of the CTF equation:
#     (a) w1: Related to the spherical aberration and electron wavelength, influencing the phase shift introduced by the lens aberrations.
#     (b) w2: Related to the defocus value and electron wavelength, affecting the overall phase shift due to defocusing.
# 2. k2: The square of the spatial frequency array k, representing the spatial frequencies at which the CTF is evaluated.
# 3. sigm: The standard deviation of the Gaussian envelope function, derived from the half-width parameter.
# 4. wi: The Gaussian envelope function, which damps the CTF at higher spatial frequencies to model the finite coherence of the electron source and other effects.
# 5. wr: The argument of the sine and cosine functions in the CTF formula, combining effects of spherical aberration and defocus.
#
# CTF Formula: The function returns the CTF as a combination of sine and cosine functions of wr, modulated by the Gaussian envelope wi and adjusted for amplitude contrast using the amplitude_contrast_ratio. This formula captures the complex interplay between phase shifts due to lens aberrations, defocus, and the damping effect of the envelope function.
#
# Key Points
# The CTF is a fundamental concept in electron microscopy, describing how the microscope modifies the phase and amplitude of the electron wave passing through the sample. The ctemh_cryoFrank function provides a detailed model of the CTF for cryo-EM, taking into account spherical aberration, defocus, electron energy, and amplitude contrast. This function is essential for simulating the imaging process in cryo-EM and for correcting the effects of the CTF in the analysis of cryo-EM data, enabling more accurate interpretation of the underlying biological structures.
#
# ##############################################################################################################

# %% [raw]
# The LocalInput class is a Python data class intended to organize and store input data for processing images, particularly in contexts where images undergo transformations based on their rotation (expressed through quaternions) and defocus values. This class is especially relevant in fields like cryo-electron microscopy (cryo-EM) or any imaging science where such parameters critically influence image analysis.
#
# Fields
#
# 1. indices: A NumPy array of integers representing global image indices. This field is used to identify specific images within a larger dataset.
# 2. quats: A 2D NumPy array of shape [4,*], where each column represents a quaternion. Quaternions are used to encode the rotation of each image in 3D space. The array size is 4xN, with N being the number of images.
# 3. defocus: A NumPy array containing the defocus values for all images. Defocus is a critical parameter in microscopy that affects image clarity and resolution.
# 4. dist_file: A string specifying the path to the output file where results (e.g., computed distances) will be stored.
# Usage
# The LocalInput class is designed to encapsulate all necessary inputs for a processing task into a single, structured object. This encapsulation simplifies passing data between functions or parts of a program, making the code cleaner and more maintainable.

# %% [raw]
# Projection Direction Data
#
# The projection direction data represents the orientations of particles or images in 3D space, as captured in cryo-electron microscopy. These orientations are critical for reconstructing the 3D structure of the imaged object (e.g., a protein or virus) from 2D projections. The projection directions are often represented on a unit sphere (S2), where each point on the sphere corresponds to a unique orientation in 3D space.
#
# How Projection Direction Data is Calculated:
#
# 1. From Euler Angles: Projection directions can be derived from Euler angles provided in the metadata of cryo-EM datasets. Euler angles (rotation, tilt, and psi) describe the orientation of each particle image relative to a reference orientation. These angles can be converted into points on a unit sphere representing the direction from which each particle was "viewed."
#
# 2. Quaternion Representation: Alternatively, orientations can be represented using quaternions, a mathematical notation that avoids the gimbal lock problem associated with Euler angles. Quaternions are converted into points on the unit sphere, similar to the conversion from Euler angles.
#
# Uniform Distribution on S2
#
# For some analyses, it might be necessary to distribute points uniformly on the unit sphere to understand the coverage of projection directions. This can be achieved through algorithms designed for uniform distribution on spheres.

# %% [raw]
# Understanding Projection Direction Data
#
# Projection directions refer to the orientations from which 2D images (projections) of a 3D object are taken. In cryo-EM, for example, each 2D image is a projection of the 3D structure of a molecule captured from a specific direction. These directions can be represented as points on a unit sphere, where each point corresponds to a direction in 3D space from which the projection was taken.
#
# How Projection Direction Data is Calculated
#
# The calculation or determination of projection directions often involves analyzing the metadata associated with each image, which includes rotation angles or other orientation parameters. These parameters can be converted into points on a unit sphere using spherical coordinates or other relevant transformations. In some cases, the directions are directly provided or can be inferred from the experimental setup.

# %% [raw]
# The _construct_input_data function is designed to prepare input data for further processing, specifically for calculating distances between images based on their projection directions, quaternions, and defocus values. This function is likely part of a larger system for analyzing cryo-electron microscopy (cryo-EM) data or similar datasets where images need to be compared based on their orientations and other parameters.
